# %% [markdown]
# <a href="https://colab.research.google.com/github/00ssum/21DL/blob/main/LOLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alshedivat/lola.git
# Out:
# Cloning into 'lola'...
# remote: Enumerating objects: 310, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 310 (delta 38), reused 34 (delta 34), pack-reused 255
# Receiving objects: 100% (310/310), 12.26 MiB | 32.26 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
cd /content/drive/MyDrive/lola
# Out:
# /content/drive/MyDrive/lola

# %%
! pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/lola
# ...
#      |████████████████████████████████| 254 kB 7.3 MB/s
# ...
#   Running setup.py develop for lola
# ...

# %%
# !pip uninstall gym
# Out:
# Found existing installation: gym 0.17.3
# Uninstalling gym-0.17.3:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/gym-0.17.3.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/gym/*
# Proceed (y/n)? y
#   Successfully uninstalled gym-0.17.3

# %%
! pip install gym==0.10.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 5.1 MB/s
# ...
#   Created wheel for gym: filename=gym-0.10.5-py3-none-any.whl size=1581307 sha256=3c81552b61975840ff91f7c8a05d45ba233c4337e35db05a549f0eae99d5ae00
#   Stored in directory: /root/.cache/pip/wheels/7a/2c/df/a05b548a40fae16ca400ecbeda0067e1a296499c1fbd7e0c9a
# Successfully built gym
# ...

# %%
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
# Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.2+zzzcolab20220527125636.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636

# %%
# !pip install tensorflow==1.15
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 412.3 MB 25 kB/s
# ...
#      |████████████████████████████████| 503 kB 65.9 MB/s
# ...
#      |████████████████████████████████| 50 kB 9.5 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 51.8 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=eb967d8ca9221875600ebeadcc3a3d1c34ed841f628a9cf0135a7c395bf5ab60
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
# ...

# %%
! python /content/drive/MyDrive/lola/scripts/run_lola.py
# Out:
# Logging to logs/IPD/seed-0
# WARNING:tensorflow:From /content/drive/MyDrive/lola/lola/train_exact.py:149: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/lola/lola/train_exact.py:20: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/lola/lola/train_exact.py:21: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/lola/lola/train_exact.py:23: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/lola/lola/train_exact.py:35: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# ...

# %%
! python /content/drive/MyDrive/lola/scripts/run_tournament.py
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# | NL-Q_vs_NL-PG_pi2   | 0.035    |
# | NL-Q_vs_NL-PG_ret1  | -2.31    |
# | NL-Q_vs_NL-PG_ret2  | -1.13    |
# | NL-Q_vs_NL-PG_v2-1  | -1.04    |
# | NL-Q_vs_NL-PG_v2-2  | -2.41    |
# | NL-Q_vs_NL-Q_pi1    | 0.46     |
# | NL-Q_vs_NL-Q_pi2    | 0.635    |
# | NL-Q_vs_NL-Q_ret1   | -1.1     |
# | NL-Q_vs_NL-Q_ret2   | -1.7     |
# | NL-Q_vs_PHC_pi1     | 0.415    |
# | NL-Q_vs_PHC_pi2     | 0.46     |
# | NL-Q_vs_PHC_ret1    | -1.21    |
# | NL-Q_vs_PHC_ret2    | -1.76    |
# | NL-Q_vs_WoLF_pi1    | 0.34     |
# | NL-Q_vs_WoLF_pi2    | 0.435    |
# | NL-Q_vs_WoLF_ret1   | -1.39    |
# | NL-Q_vs_WoLF_ret2   | -1.75    |
# | PHC_vs_LOLA_pi1     | 0.455    |
# | PHC_vs_LOLA_pi2     | 0.005    |
# | PHC_vs_LOLA_ret1    | -2.3     |
# | PHC_vs_LOLA_ret2    | -1.27    |
# | PHC_vs_LOLA_v2-1    | -1.39    |
# | PHC_vs_LOLA_v2-2    | -1.72    |
# | PHC_vs_NL-PG_pi1    | 0.48     |
# | PHC_vs_NL-PG_pi2    | 0.24     |
# | PHC_vs_NL-PG_ret1   | -2.03    |
# ...

# %%
! python /content/drive/MyDrive/lola/notebooks/tournament/analysis.ipynb
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/lola/notebooks/tournament/analysis.ipynb", line 31, in <module>
#     "collapsed": true
# NameError: name 'true' is not defined
